# %% [markdown]
# # Google Search Analysis

# %% [markdown]
# Google doesn’t give much access to the data about daily search queries, but another application of google known as Google Trends can be used for the task of Google search analysis. Google Trends provides an API that can be used to analyze the daily searches on Google. This API is known as pytrends, you can easily install it in your systems by using the pip command;
# ***pip install pytrends***

# %%
pip install pytrends

# %% [markdown]
# ## Importing Libraries

# %%
import pandas
from pytrends.request import TrendReq
import matplotlib.pyplot as plt

# %%
trends = TrendReq()

# %% [markdown]
# Analyzing the Google search trends on the queries based on "Machine Learning". Let's create a DataFrame of top 10 countries which search for "Machine Learning"

# %%
trends.build_payload(kw_list=["Machine Learning"])
data = trends.interest_by_region()
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#              Machine Learning
# geoName
# China                     100
# Ethiopia                   43
# Singapore                  43
# St. Helena                 33
# India                      32
# Tunisia                    23
# Hong Kong                  23
# Pakistan                   22
# Nepal                      21
# South Korea                21

# %% [markdown]
# ## Visualizing the Results

# %%
data.reset_index().plot(x="geoName", 
                        y="Machine Learning",
                        figsize=(15, 12),
                        kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# ## Trend of "Machine Learning" search query in Google over time

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Machine Learning'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 12))
data['Machine Learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Goolge Searches for Machine Learning', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# From the graph, we can see that there is a huge spike of increase in the searches about "Machine Learning" on Google in the year 2022. This is how the Google Search Analysis can be perfomed based on any keyword. This Analysis can be useful for the SEO (Search Engine Optimization) of the websites with respect to the countries they can reach. A business can perform Google search analysis to understand what people are looking for on Google at any given time.
